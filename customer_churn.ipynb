# %% [markdown]
# <a href="https://colab.research.google.com/github/cheran1303/MAIN-py/blob/main/customer_churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install kaggle

# %%
# !kaggle datasets download -d shantanudhakadd/bank-customer-churn-prediction
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'

# %%
# !kaggle datasets download -d shantanudhakadd/bank-customer-churn-prediction
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shantanudhakadd/bank-customer-churn-prediction")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 262k/262k [00:00<00:00, 70.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/shantanudhakadd/bank-customer-churn-prediction/versions/1

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "Churn_Modelling.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "shantanudhakadd/bank-customer-churn-prediction",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("Random 10 records:", df.sample(10))
# Count the number of customers who stayed (0) and who churned (1)
churn_counts = df['Exited'].value_counts()

# Display the counts
print("Total number of customers who stayed and churned:")
display(churn_counts)

min_values = df.min(numeric_only=True)
print(min_values)
# Out:
# /tmp/ipython-input-3836437330.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 669k/669k [00:00<00:00, 74.6MB/s]
# Random 10 records:       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 996         997    15645621           Hunter          811     Spain    Male
# 3772       3773    15699486          Johnson          745     Spain    Male
# 3818       3819    15740147        Cremonesi          725    France  Female
# 5564       5565    15700083              Lai          609     Spain    Male
# 3791       3792    15795151         Hartzler          705    France  Female
# 5277       5278    15589924      Rapuluolisa          577     Spain  Female
# 5943       5944    15658813        Siciliani          645    France  Female
# 2661       2662    15688409        Donaldson          742    France  Female
# ...

# %%
# List the files in the downloaded dataset directory to find the correct filename
# !ls /root/.cache/kagglehub/datasets/shantanudhakadd/bank-customer-churn-prediction/versions/1
# Out:
# Churn_Modelling.csv

# %%
# Display 5 random rows from the DataFrame
display(df.sample(5))
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  \
# 6904       6905    15627185     Terry          744   Germany   Male   29
# 5105       5106    15718465    Sadler          671   Germany   Male   51
# 737         738    15766741  McIntyre          525    France   Male   36
# 4033       4034    15569079    Hagins          632   Germany   Male   48
# 2544       2545    15709487   Freeman          668   Germany   Male   34
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6904       6  123737.04              2          1               0
# 5105       3   96891.46              1          1               0
# 737        2  114628.40              1          0               1
# 4033       6  126066.26              1          1               0
# 2544       5   80242.37              2          0               0
#
#       EstimatedSalary  Exited
# 6904        141558.04       0
# 5105        176403.33       1
# 737         168290.06       0
# ...

# %%
# Display the entire DataFrame
display(df)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...
